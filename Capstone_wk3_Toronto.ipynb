# %%
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 

from geopy.geocoders import Nominatim 

import requests 
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

import folium

# %%
file_to_open = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
df = pd.read_html(file_to_open)[0]
df.head(5)
# Out:
#                                                    0                1  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                                 2  \
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned
#
#                                                 3  \
# 0                 M4ANorth York(Victoria Village)
# 1  M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                  M4CEast York(Woodbine Heights)
# 3                    M4EEast Toronto(The Beaches)
# 4                           M4GEast York(Leaside)
#
#                                                  4  \
# 0  M5ADowntown Toronto(Regent Park / Harbourfront)
# 1    M5BDowntown Toronto(Garden District, Ryerson)
# 2              M5CDowntown Toronto(St. James Town)
# 3                 M5EDowntown Toronto(Berczy Park)
# 4          M5GDowntown Toronto(Central Bay Street)
#
#                                                   5  \
# 0  M6ANorth York(Lawrence Manor / Lawrence Heights)
# 1                          M6BNorth York(Glencairn)
# 2                       M6CYork(Humewood-Cedarvale)
# 3                      M6EYork(Caledonia-Fairbanks)
# 4                     M6GDowntown Toronto(Christie)
#
#                                                  6                7  \
# 0  M7AQueen's Park / Ontario Provincial Government  M8ANot assigned
# 1                                  M7BNot assigned  M8BNot assigned
# 2                                  M7CNot assigned  M8CNot assigned
# 3                                  M7ENot assigned  M8ENot assigned
# 4                                  M7GNot assigned  M8GNot assigned
#
#                                                    8
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
# convert grid format to a set rows:
df = df.stack() 
#now we have a Pandas series(1D), which we convert back to a dataframe (2D)
df = df.to_frame()
df.columns = ['data']
df.head()
# Out:
#                                                 data
# 0 0                                  M1ANot assigned
#   1                                  M2ANot assigned
#   2                         M3ANorth York(Parkwoods)
#   3                  M4ANorth York(Victoria Village)
#   4  M5ADowntown Toronto(Regent Park / Harbourfront)

# %%
# Pandas messing about with index, lets reset 
df.reset_index(drop=True,inplace=True)

# %%
# each cell starts with a 3 digits postal code which we extract
df['PostalCode'] = df['data'].str[:3]
df['data'] = df['data'].str[3:]
df.head()
# Out:
#                                            data PostalCode
# 0                                  Not assigned        M1A
# 1                                  Not assigned        M2A
# 2                         North York(Parkwoods)        M3A
# 3                  North York(Victoria Village)        M4A
# 4  Downtown Toronto(Regent Park / Harbourfront)        M5A

# %%
# Extract the portion within the parentheses to a new colomn Neighborhood
df['Neighborhood'] = df['data'].str.extract('\((.*?)\)')
df
# Out:
#                                                   data PostalCode  \
# 0                                         Not assigned        M1A
# 1                                         Not assigned        M2A
# 2                                North York(Parkwoods)        M3A
# 3                         North York(Victoria Village)        M4A
# 4         Downtown Toronto(Regent Park / Harbourfront)        M5A
# 5        North York(Lawrence Manor / Lawrence Heights)        M6A
# 6         Queen's Park / Ontario Provincial Government        M7A
# 7                                         Not assigned        M8A
# 8                          Etobicoke(Islington Avenue)        M9A
# 9                         Scarborough(Malvern / Rouge)        M1B
# 10                                        Not assigned        M2B
# 11                          North York(Don Mills)North        M3B
# 12         East York(Parkview Hill / Woodbine Gardens)        M4B
# 13          Downtown Toronto(Garden District, Ryerson)        M5B
# 14                               North York(Glencairn)        M6B
# 15                                        Not assigned        M7B
# 16                                        Not assigned        M8B
# 17   Etobicoke(West Deane Park / Princess Gardens /...        M9B
# 18   Scarborough(Rouge Hill / Port Union / Highland...        M1C
# 19                                        Not assigned        M2C
# 20         North York(Don Mills)South(Flemingdon Park)        M3C
# 21                         East York(Woodbine Heights)        M4C
# 22                    Downtown Toronto(St. James Town)        M5C
# 23                            York(Humewood-Cedarvale)        M6C
# 24                                        Not assigned        M7C
# 25                                        Not assigned        M8C
# 26   Etobicoke(Eringate / Bloordale Gardens / Old B...        M9C
# 27    Scarborough(Guildwood / Morningside / West Hill)        M1E
# 28                                        Not assigned        M2E
# 29                                        Not assigned        M3E
# 30                           East Toronto(The Beaches)        M4E
# 31                       Downtown Toronto(Berczy Park)        M5E
# 32                           York(Caledonia-Fairbanks)        M6E
# 33                                        Not assigned        M7E
# 34                                        Not assigned        M8E
# 35                                        Not assigned        M9E
# 36                                 Scarborough(Woburn)        M1G
# 37                                        Not assigned        M2G
# 38                                        Not assigned        M3G
# 39                                  East York(Leaside)        M4G
# 40                Downtown Toronto(Central Bay Street)        M5G
# 41                          Downtown Toronto(Christie)        M6G
# 42                                        Not assigned        M7G
# 43                                        Not assigned        M8G
# 44                                        Not assigned        M9G
# 45                              Scarborough(Cedarbrae)        M1H
# 46                       North York(Hillcrest Village)        M2H
# 47   North York(Bathurst Manor / Wilson Heights / D...        M3H
# 48                         East York(Thorncliffe Park)        M4H
# 49        Downtown Toronto(Richmond / Adelaide / King)        M5H
# 50         West Toronto(Dufferin / Dovercourt Village)        M6H
# 51                                        Not assigned        M7H
# 52                                        Not assigned        M8H
# 53                                        Not assigned        M9H
# 54                    Scarborough(Scarborough Village)        M1J
# 55          North York(Fairview / Henry Farm / Oriole)        M2J
# 56        North York(Northwood Park / York University)        M3J
# 57            East YorkEast Toronto(The Danforth East)        M4J
# 58   Downtown Toronto(Harbourfront East / Union Sta...        M5J
# 59             West Toronto(Little Portugal / Trinity)        M6J
# 60                                        Not assigned        M7J
# 61                                        Not assigned        M8J
# 62                                        Not assigned        M9J
# 63   Scarborough(Kennedy Park / Ionview / East Birc...        M1K
# 64                         North York(Bayview Village)        M2K
# 65             North York(Downsview)East (CFB Toronto)        M3K
# 66         East Toronto(The Danforth West / Riverdale)        M4K
# 67   Downtown Toronto(Toronto Dominion Centre / Des...        M5K
# 68   West Toronto(Brockton / Parkdale Village / Exh...        M6K
# 69                                        Not assigned        M7K
# 70                                        Not assigned        M8K
# 71                                        Not assigned        M9K
# 72      Scarborough(Golden Mile / Clairlea / Oakridge)        M1L
# 73               North York(York Mills / Silver Hills)        M2L
# 74                           North York(Downsview)West        M3L
# 75       East Toronto(India Bazaar / The Beaches West)        M4L
# 76   Downtown Toronto(Commerce Court / Victoria Hotel)        M5L
# 77   North York(North Park / Maple Leaf Park / Upwo...        M6L
# 78                                        Not assigned        M7L
# 79                                        Not assigned        M8L
# 80                           North York(Humber Summit)        M9L
# 81   Scarborough(Cliffside / Cliffcrest / Scarborou...        M1M
# 82                North York(Willowdale / Newtonbrook)        M2M
# 83                        North York(Downsview)Central        M3M
# 84                       East Toronto(Studio District)        M4M
# 85      North York(Bedford Park / Lawrence Manor East)        M5M
# 86   York(Del Ray / Mount Dennis / Keelsdale and Si...        M6M
# 87                                        Not assigned        M7M
# 88                                        Not assigned        M8M
# 89                       North York(Humberlea / Emery)        M9M
# 90           Scarborough(Birch Cliff / Cliffside West)        M1N
# 91                         North York(Willowdale)South        M2N
# 92                      North York(Downsview)Northwest        M3N
# 93                      Central Toronto(Lawrence Park)        M4N
# 94                           Central Toronto(Roselawn)        M5N
# 95                York(Runnymede / The Junction North)        M6N
# 96                                        Not assigned        M7N
# 97                                        Not assigned        M8N
# 98                                        York(Weston)        M9N
# 99   Scarborough(Dorset Park / Wexford Heights / Sc...        M1P
# 100                        North York(York Mills West)        M2P
# 101                                       Not assigned        M3P
# 102                  Central Toronto(Davisville North)        M4P
# 103          Central Toronto(Forest Hill North & West)        M5P
# 104       West Toronto(High Park / The Junction South)        M6P
# 105                                       Not assigned        M7P
# 106                                       Not assigned        M8P
# 107                               Etobicoke(Westmount)        M9P
# 108                    Scarborough(Wexford / Maryvale)        M1R
# 109                         North York(Willowdale)West        M2R
# 110                                       Not assigned        M3R
# 111                Central Toronto(North Toronto West)        M4R
# 112  Central Toronto(The Annex / North Midtown / Yo...        M5R
# 113              West Toronto(Parkdale / Roncesvalles)        M6R
# 114  MississaugaCanada Post Gateway Processing Cent...        M7R
# 115                                       Not assigned        M8R
# 116  Etobicoke(Kingsview Village / St. Phillips / M...        M9R
# 117                             Scarborough(Agincourt)        M1S
# 118                                       Not assigned        M2S
# 119                                       Not assigned        M3S
# 120                        Central Toronto(Davisville)        M4S
# 121  Downtown Toronto(University of Toronto / Harbord)        M5S
# 122                  West Toronto(Runnymede / Swansea)        M6S
# 123                                       Not assigned        M7S
# 124                                       Not assigned        M8S
# 125                                       Not assigned        M9S
# 126  Scarborough(Clarks Corners / Tam O'Shanter / S...        M1T
# 127                                       Not assigned        M2T
# 128                                       Not assigned        M3T
# 129      Central Toronto(Moore Park / Summerhill East)        M4T
# 130  Downtown Toronto(Kensington Market / Chinatown...        M5T
# 131                                       Not assigned        M6T
# 132                                       Not assigned        M7T
# 133                                       Not assigned        M8T
# 134                                       Not assigned        M9T
# 135  Scarborough(Milliken / Agincourt North / Steel...        M1V
# 136                                       Not assigned        M2V
# 137                                       Not assigned        M3V
# 138  Central Toronto(Summerhill West / Rathnelly / ...        M4V
# 139  Downtown Toronto(CN Tower / King and Spadina /...        M5V
# 140                                       Not assigned        M6V
# 141                                       Not assigned        M7V
# 142  Etobicoke(New Toronto / Mimico South / Humber ...        M8V
# 143  Etobicoke(South Steeles / Silverstone / Humber...        M9V
# 144        Scarborough(Steeles West / L'Amoreaux West)        M1W
# 145                                       Not assigned        M2W
# 146                                       Not assigned        M3W
# 147                         Downtown Toronto(Rosedale)        M4W
# 148  Downtown TorontoStn A PO Boxes25 The Esplanade...        M5W
# 149                                       Not assigned        M6W
# 150                                       Not assigned        M7W
# 151                 Etobicoke(Alderwood / Long Branch)        M8W
# 152  EtobicokeNorthwest(Clairville / Humberwood / W...        M9W
# 153                           Scarborough(Upper Rouge)        M1X
# 154                                       Not assigned        M2X
# 155                                       Not assigned        M3X
# 156     Downtown Toronto(St. James Town / Cabbagetown)        M4X
# 157  Downtown Toronto(First Canadian Place / Underg...        M5X
# 158                                       Not assigned        M6X
# 159                                       Not assigned        M7X
# 160  Etobicoke(The Kingsway / Montgomery Road / Old...        M8X
# 161                                       Not assigned        M9X
# 162                                       Not assigned        M1Y
# 163                                       Not assigned        M2Y
# 164                                       Not assigned        M3Y
# 165             Downtown Toronto(Church and Wellesley)        M4Y
# 166                                       Not assigned        M5Y
# 167                                       Not assigned        M6Y
# 168  East TorontoBusiness reply mail Processing Cen...        M7Y
# 169  Etobicoke(Old Mill South / King's Mill Park / ...        M8Y
# 170                                       Not assigned        M9Y
# 171                                       Not assigned        M1Z
# 172                                       Not assigned        M2Z
# 173                                       Not assigned        M3Z
# 174                                       Not assigned        M4Z
# 175                                       Not assigned        M5Z
# 176                                       Not assigned        M6Z
# 177                                       Not assigned        M7Z
# 178  Etobicoke(Mimico NW / The Queensway West / Sou...        M8Z
# 179                                       Not assigned        M9Z
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# 5                    Lawrence Manor / Lawrence Heights
# 6                                                  NaN
# 7                                                  NaN
# 8                                     Islington Avenue
# 9                                      Malvern / Rouge
# 10                                                 NaN
# 11                                           Don Mills
# 12                    Parkview Hill / Woodbine Gardens
# 13                            Garden District, Ryerson
# 14                                           Glencairn
# 15                                                 NaN
# 16                                                 NaN
# 17   West Deane Park / Princess Gardens / Martin Gr...
# 18            Rouge Hill / Port Union / Highland Creek
# 19                                                 NaN
# 20                                           Don Mills
# 21                                    Woodbine Heights
# 22                                      St. James Town
# 23                                  Humewood-Cedarvale
# 24                                                 NaN
# 25                                                 NaN
# 26   Eringate / Bloordale Gardens / Old Burnhamthor...
# 27                 Guildwood / Morningside / West Hill
# 28                                                 NaN
# 29                                                 NaN
# 30                                         The Beaches
# 31                                         Berczy Park
# 32                                 Caledonia-Fairbanks
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                              Woburn
# 37                                                 NaN
# 38                                                 NaN
# 39                                             Leaside
# 40                                  Central Bay Street
# 41                                            Christie
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                           Cedarbrae
# 46                                   Hillcrest Village
# 47   Bathurst Manor / Wilson Heights / Downsview North
# 48                                    Thorncliffe Park
# 49                          Richmond / Adelaide / King
# 50                       Dufferin / Dovercourt Village
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 54                                 Scarborough Village
# 55                      Fairview / Henry Farm / Oriole
# 56                    Northwood Park / York University
# 57                                   The Danforth East
# 58   Harbourfront East / Union Station / Toronto Is...
# 59                           Little Portugal / Trinity
# 60                                                 NaN
# 61                                                 NaN
# 62                                                 NaN
# 63       Kennedy Park / Ionview / East Birchmount Park
# 64                                     Bayview Village
# 65                                           Downsview
# 66                       The Danforth West / Riverdale
# 67           Toronto Dominion Centre / Design Exchange
# 68      Brockton / Parkdale Village / Exhibition Place
# 69                                                 NaN
# 70                                                 NaN
# 71                                                 NaN
# 72                   Golden Mile / Clairlea / Oakridge
# 73                           York Mills / Silver Hills
# 74                                           Downsview
# 75                     India Bazaar / The Beaches West
# 76                     Commerce Court / Victoria Hotel
# 77          North Park / Maple Leaf Park / Upwood Park
# 78                                                 NaN
# 79                                                 NaN
# 80                                       Humber Summit
# 81   Cliffside / Cliffcrest / Scarborough Village West
# 82                            Willowdale / Newtonbrook
# 83                                           Downsview
# 84                                     Studio District
# 85                  Bedford Park / Lawrence Manor East
# 86   Del Ray / Mount Dennis / Keelsdale and Silvert...
# 87                                                 NaN
# 88                                                 NaN
# 89                                   Humberlea / Emery
# 90                        Birch Cliff / Cliffside West
# 91                                          Willowdale
# 92                                           Downsview
# 93                                       Lawrence Park
# 94                                            Roselawn
# 95                      Runnymede / The Junction North
# 96                                                 NaN
# 97                                                 NaN
# 98                                              Weston
# 99   Dorset Park / Wexford Heights / Scarborough To...
# 100                                    York Mills West
# 101                                                NaN
# 102                                   Davisville North
# 103                           Forest Hill North & West
# 104                     High Park / The Junction South
# 105                                                NaN
# 106                                                NaN
# 107                                          Westmount
# 108                                 Wexford / Maryvale
# 109                                         Willowdale
# 110                                                NaN
# 111                                 North Toronto West
# 112              The Annex / North Midtown / Yorkville
# 113                            Parkdale / Roncesvalles
# 114                                     Enclave of L4W
# 115                                                NaN
# 116  Kingsview Village / St. Phillips / Martin Grov...
# 117                                          Agincourt
# 118                                                NaN
# 119                                                NaN
# 120                                         Davisville
# 121                    University of Toronto / Harbord
# 122                                Runnymede / Swansea
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126          Clarks Corners / Tam O'Shanter / Sullivan
# 127                                                NaN
# 128                                                NaN
# 129                       Moore Park / Summerhill East
# 130        Kensington Market / Chinatown / Grange Park
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135  Milliken / Agincourt North / Steeles East / L'...
# 136                                                NaN
# 137                                                NaN
# 138  Summerhill West / Rathnelly / South Hill / For...
# 139  CN Tower / King and Spadina / Railway Lands / ...
# 140                                                NaN
# 141                                                NaN
# 142     New Toronto / Mimico South / Humber Bay Shores
# 143  South Steeles / Silverstone / Humbergate / Jam...
# 144                     Steeles West / L'Amoreaux West
# 145                                                NaN
# 146                                                NaN
# 147                                           Rosedale
# 148                                     Enclave of M5E
# 149                                                NaN
# 150                                                NaN
# 151                            Alderwood / Long Branch
# 152  Clairville / Humberwood / Woodbine Downs / Wes...
# 153                                        Upper Rouge
# 154                                                NaN
# 155                                                NaN
# 156                       St. James Town / Cabbagetown
# 157            First Canadian Place / Underground city
# 158                                                NaN
# 159                                                NaN
# 160    The Kingsway / Montgomery Road / Old Mill North
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                               Church and Wellesley
# 166                                                NaN
# 167                                                NaN
# 168                                     Enclave of M4L
# 169  Old Mill South / King's Mill Park / Sunnylea /...
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW / The Queensway West / South of Bloo...
# 179                                                NaN

# %%
# Remove the neighborhood so that only the borough remains
df['Borough'] = df['data'].str.split('(').str[0]
df.head()
# Out:
#                                            data PostalCode  \
# 0                                  Not assigned        M1A
# 1                                  Not assigned        M2A
# 2                         North York(Parkwoods)        M3A
# 3                  North York(Victoria Village)        M4A
# 4  Downtown Toronto(Regent Park / Harbourfront)        M5A
#
#                  Neighborhood           Borough
# 0                         NaN      Not assigned
# 1                         NaN      Not assigned
# 2                   Parkwoods        North York
# 3            Victoria Village        North York
# 4  Regent Park / Harbourfront  Downtown Toronto

# %%
# no longer necessary
df.drop(columns = ['data'], inplace=True)

# %%
# rearange columns
df = df[['PostalCode', 'Borough', 'Neighborhood']]
df.head()
# Out:
#   PostalCode           Borough                Neighborhood
# 0        M1A      Not assigned                         NaN
# 1        M2A      Not assigned                         NaN
# 2        M3A        North York                   Parkwoods
# 3        M4A        North York            Victoria Village
# 4        M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
# replace / with , and rmove space
df['Neighborhood'] = df['Neighborhood'].str.replace(' /', ',')
df
# Out:
#     PostalCode                                            Borough  \
# 0          M1A                                       Not assigned
# 1          M2A                                       Not assigned
# 2          M3A                                         North York
# 3          M4A                                         North York
# 4          M5A                                   Downtown Toronto
# 5          M6A                                         North York
# 6          M7A       Queen's Park / Ontario Provincial Government
# 7          M8A                                       Not assigned
# 8          M9A                                          Etobicoke
# 9          M1B                                        Scarborough
# 10         M2B                                       Not assigned
# 11         M3B                                         North York
# 12         M4B                                          East York
# 13         M5B                                   Downtown Toronto
# 14         M6B                                         North York
# 15         M7B                                       Not assigned
# 16         M8B                                       Not assigned
# 17         M9B                                          Etobicoke
# 18         M1C                                        Scarborough
# 19         M2C                                       Not assigned
# 20         M3C                                         North York
# 21         M4C                                          East York
# 22         M5C                                   Downtown Toronto
# 23         M6C                                               York
# 24         M7C                                       Not assigned
# 25         M8C                                       Not assigned
# 26         M9C                                          Etobicoke
# 27         M1E                                        Scarborough
# 28         M2E                                       Not assigned
# 29         M3E                                       Not assigned
# 30         M4E                                       East Toronto
# 31         M5E                                   Downtown Toronto
# 32         M6E                                               York
# 33         M7E                                       Not assigned
# 34         M8E                                       Not assigned
# 35         M9E                                       Not assigned
# 36         M1G                                        Scarborough
# 37         M2G                                       Not assigned
# 38         M3G                                       Not assigned
# 39         M4G                                          East York
# 40         M5G                                   Downtown Toronto
# 41         M6G                                   Downtown Toronto
# 42         M7G                                       Not assigned
# 43         M8G                                       Not assigned
# 44         M9G                                       Not assigned
# 45         M1H                                        Scarborough
# 46         M2H                                         North York
# 47         M3H                                         North York
# 48         M4H                                          East York
# 49         M5H                                   Downtown Toronto
# 50         M6H                                       West Toronto
# 51         M7H                                       Not assigned
# 52         M8H                                       Not assigned
# 53         M9H                                       Not assigned
# 54         M1J                                        Scarborough
# 55         M2J                                         North York
# 56         M3J                                         North York
# 57         M4J                              East YorkEast Toronto
# 58         M5J                                   Downtown Toronto
# 59         M6J                                       West Toronto
# 60         M7J                                       Not assigned
# 61         M8J                                       Not assigned
# 62         M9J                                       Not assigned
# 63         M1K                                        Scarborough
# 64         M2K                                         North York
# 65         M3K                                         North York
# 66         M4K                                       East Toronto
# 67         M5K                                   Downtown Toronto
# 68         M6K                                       West Toronto
# 69         M7K                                       Not assigned
# 70         M8K                                       Not assigned
# 71         M9K                                       Not assigned
# 72         M1L                                        Scarborough
# 73         M2L                                         North York
# 74         M3L                                         North York
# 75         M4L                                       East Toronto
# 76         M5L                                   Downtown Toronto
# 77         M6L                                         North York
# 78         M7L                                       Not assigned
# 79         M8L                                       Not assigned
# 80         M9L                                         North York
# 81         M1M                                        Scarborough
# 82         M2M                                         North York
# 83         M3M                                         North York
# 84         M4M                                       East Toronto
# 85         M5M                                         North York
# 86         M6M                                               York
# 87         M7M                                       Not assigned
# 88         M8M                                       Not assigned
# 89         M9M                                         North York
# 90         M1N                                        Scarborough
# 91         M2N                                         North York
# 92         M3N                                         North York
# 93         M4N                                    Central Toronto
# 94         M5N                                    Central Toronto
# 95         M6N                                               York
# 96         M7N                                       Not assigned
# 97         M8N                                       Not assigned
# 98         M9N                                               York
# 99         M1P                                        Scarborough
# 100        M2P                                         North York
# 101        M3P                                       Not assigned
# 102        M4P                                    Central Toronto
# 103        M5P                                    Central Toronto
# 104        M6P                                       West Toronto
# 105        M7P                                       Not assigned
# 106        M8P                                       Not assigned
# 107        M9P                                          Etobicoke
# 108        M1R                                        Scarborough
# 109        M2R                                         North York
# 110        M3R                                       Not assigned
# 111        M4R                                    Central Toronto
# 112        M5R                                    Central Toronto
# 113        M6R                                       West Toronto
# 114        M7R   MississaugaCanada Post Gateway Processing Centre
# 115        M8R                                       Not assigned
# 116        M9R                                          Etobicoke
# 117        M1S                                        Scarborough
# 118        M2S                                       Not assigned
# 119        M3S                                       Not assigned
# 120        M4S                                    Central Toronto
# 121        M5S                                   Downtown Toronto
# 122        M6S                                       West Toronto
# 123        M7S                                       Not assigned
# 124        M8S                                       Not assigned
# 125        M9S                                       Not assigned
# 126        M1T                                        Scarborough
# 127        M2T                                       Not assigned
# 128        M3T                                       Not assigned
# 129        M4T                                    Central Toronto
# 130        M5T                                   Downtown Toronto
# 131        M6T                                       Not assigned
# 132        M7T                                       Not assigned
# 133        M8T                                       Not assigned
# 134        M9T                                       Not assigned
# 135        M1V                                        Scarborough
# 136        M2V                                       Not assigned
# 137        M3V                                       Not assigned
# 138        M4V                                    Central Toronto
# 139        M5V                                   Downtown Toronto
# 140        M6V                                       Not assigned
# 141        M7V                                       Not assigned
# 142        M8V                                          Etobicoke
# 143        M9V                                          Etobicoke
# 144        M1W                                        Scarborough
# 145        M2W                                       Not assigned
# 146        M3W                                       Not assigned
# 147        M4W                                   Downtown Toronto
# 148        M5W     Downtown TorontoStn A PO Boxes25 The Esplanade
# 149        M6W                                       Not assigned
# 150        M7W                                       Not assigned
# 151        M8W                                          Etobicoke
# 152        M9W                                 EtobicokeNorthwest
# 153        M1X                                        Scarborough
# 154        M2X                                       Not assigned
# 155        M3X                                       Not assigned
# 156        M4X                                   Downtown Toronto
# 157        M5X                                   Downtown Toronto
# 158        M6X                                       Not assigned
# 159        M7X                                       Not assigned
# 160        M8X                                          Etobicoke
# 161        M9X                                       Not assigned
# 162        M1Y                                       Not assigned
# 163        M2Y                                       Not assigned
# 164        M3Y                                       Not assigned
# 165        M4Y                                   Downtown Toronto
# 166        M5Y                                       Not assigned
# 167        M6Y                                       Not assigned
# 168        M7Y  East TorontoBusiness reply mail Processing Cen...
# 169        M8Y                                          Etobicoke
# 170        M9Y                                       Not assigned
# 171        M1Z                                       Not assigned
# 172        M2Z                                       Not assigned
# 173        M3Z                                       Not assigned
# 174        M4Z                                       Not assigned
# 175        M5Z                                       Not assigned
# 176        M6Z                                       Not assigned
# 177        M7Z                                       Not assigned
# 178        M8Z                                          Etobicoke
# 179        M9Z                                       Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6                                                  NaN
# 7                                                  NaN
# 8                                     Islington Avenue
# 9                                       Malvern, Rouge
# 10                                                 NaN
# 11                                           Don Mills
# 12                     Parkview Hill, Woodbine Gardens
# 13                            Garden District, Ryerson
# 14                                           Glencairn
# 15                                                 NaN
# 16                                                 NaN
# 17   West Deane Park, Princess Gardens, Martin Grov...
# 18              Rouge Hill, Port Union, Highland Creek
# 19                                                 NaN
# 20                                           Don Mills
# 21                                    Woodbine Heights
# 22                                      St. James Town
# 23                                  Humewood-Cedarvale
# 24                                                 NaN
# 25                                                 NaN
# 26   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 27                   Guildwood, Morningside, West Hill
# 28                                                 NaN
# 29                                                 NaN
# 30                                         The Beaches
# 31                                         Berczy Park
# 32                                 Caledonia-Fairbanks
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                              Woburn
# 37                                                 NaN
# 38                                                 NaN
# 39                                             Leaside
# 40                                  Central Bay Street
# 41                                            Christie
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                           Cedarbrae
# 46                                   Hillcrest Village
# 47     Bathurst Manor, Wilson Heights, Downsview North
# 48                                    Thorncliffe Park
# 49                            Richmond, Adelaide, King
# 50                        Dufferin, Dovercourt Village
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 54                                 Scarborough Village
# 55                        Fairview, Henry Farm, Oriole
# 56                     Northwood Park, York University
# 57                                   The Danforth East
# 58   Harbourfront East, Union Station, Toronto Islands
# 59                            Little Portugal, Trinity
# 60                                                 NaN
# 61                                                 NaN
# 62                                                 NaN
# 63         Kennedy Park, Ionview, East Birchmount Park
# 64                                     Bayview Village
# 65                                           Downsview
# 66                        The Danforth West, Riverdale
# 67            Toronto Dominion Centre, Design Exchange
# 68        Brockton, Parkdale Village, Exhibition Place
# 69                                                 NaN
# 70                                                 NaN
# 71                                                 NaN
# 72                     Golden Mile, Clairlea, Oakridge
# 73                            York Mills, Silver Hills
# 74                                           Downsview
# 75                      India Bazaar, The Beaches West
# 76                      Commerce Court, Victoria Hotel
# 77            North Park, Maple Leaf Park, Upwood Park
# 78                                                 NaN
# 79                                                 NaN
# 80                                       Humber Summit
# 81     Cliffside, Cliffcrest, Scarborough Village West
# 82                             Willowdale, Newtonbrook
# 83                                           Downsview
# 84                                     Studio District
# 85                   Bedford Park, Lawrence Manor East
# 86    Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 87                                                 NaN
# 88                                                 NaN
# 89                                    Humberlea, Emery
# 90                         Birch Cliff, Cliffside West
# 91                                          Willowdale
# 92                                           Downsview
# 93                                       Lawrence Park
# 94                                            Roselawn
# 95                       Runnymede, The Junction North
# 96                                                 NaN
# 97                                                 NaN
# 98                                              Weston
# 99   Dorset Park, Wexford Heights, Scarborough Town...
# 100                                    York Mills West
# 101                                                NaN
# 102                                   Davisville North
# 103                           Forest Hill North & West
# 104                      High Park, The Junction South
# 105                                                NaN
# 106                                                NaN
# 107                                          Westmount
# 108                                  Wexford, Maryvale
# 109                                         Willowdale
# 110                                                NaN
# 111                                 North Toronto West
# 112                The Annex, North Midtown, Yorkville
# 113                             Parkdale, Roncesvalles
# 114                                     Enclave of L4W
# 115                                                NaN
# 116  Kingsview Village, St. Phillips, Martin Grove ...
# 117                                          Agincourt
# 118                                                NaN
# 119                                                NaN
# 120                                         Davisville
# 121                     University of Toronto, Harbord
# 122                                 Runnymede, Swansea
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126            Clarks Corners, Tam O'Shanter, Sullivan
# 127                                                NaN
# 128                                                NaN
# 129                        Moore Park, Summerhill East
# 130          Kensington Market, Chinatown, Grange Park
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135  Milliken, Agincourt North, Steeles East, L'Amo...
# 136                                                NaN
# 137                                                NaN
# 138  Summerhill West, Rathnelly, South Hill, Forest...
# 139  CN Tower, King and Spadina, Railway Lands, Har...
# 140                                                NaN
# 141                                                NaN
# 142       New Toronto, Mimico South, Humber Bay Shores
# 143  South Steeles, Silverstone, Humbergate, Jamest...
# 144                      Steeles West, L'Amoreaux West
# 145                                                NaN
# 146                                                NaN
# 147                                           Rosedale
# 148                                     Enclave of M5E
# 149                                                NaN
# 150                                                NaN
# 151                             Alderwood, Long Branch
# 152  Clairville, Humberwood, Woodbine Downs, West H...
# 153                                        Upper Rouge
# 154                                                NaN
# 155                                                NaN
# 156                        St. James Town, Cabbagetown
# 157             First Canadian Place, Underground city
# 158                                                NaN
# 159                                                NaN
# 160      The Kingsway, Montgomery Road, Old Mill North
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                               Church and Wellesley
# 166                                                NaN
# 167                                                NaN
# 168                                     Enclave of M4L
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                                NaN

# %%
# Boolean mask to identify where Neighborhood field empty but borough is not
mask1 = ((df['Neighborhood'].isnull()) & (df['Borough'] != "Not assigned"))
mask1.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
# apply mask
df['Neighborhood'][mask1] = df['Borough']
df.head(7)
# Out:
#   PostalCode                                       Borough  \
# 0        M1A                                  Not assigned
# 1        M2A                                  Not assigned
# 2        M3A                                    North York
# 3        M4A                                    North York
# 4        M5A                              Downtown Toronto
# 5        M6A                                    North York
# 6        M7A  Queen's Park / Ontario Provincial Government
#
#                                    Neighborhood
# 0                                           NaN
# 1                                           NaN
# 2                                     Parkwoods
# 3                              Victoria Village
# 4                     Regent Park, Harbourfront
# 5              Lawrence Manor, Lawrence Heights
# 6  Queen's Park / Ontario Provincial Government

# %%
# remove postal codes that have no borough assigned 
df.drop(df[df.Borough =="Not assigned"].index, inplace=True)

# %%
# reset index numbering
df.index = np.arange(len(df))
df.head()
# Out:
#   PostalCode                                       Borough  \
# 0        M3A                                    North York
# 1        M4A                                    North York
# 2        M5A                              Downtown Toronto
# 3        M6A                                    North York
# 4        M7A  Queen's Park / Ontario Provincial Government
#
#                                    Neighborhood
# 0                                     Parkwoods
# 1                              Victoria Village
# 2                     Regent Park, Harbourfront
# 3              Lawrence Manor, Lawrence Heights
# 4  Queen's Park / Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)
